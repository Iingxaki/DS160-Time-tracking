# %% [markdown]
# # Programming Project 1 analysis using EDA tools
# - Name: Radjamin Hukom
# - Date: 10/3/2023
# - Version: 1

# %% [markdown]
# ### Import Modules

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Load the dataset and save it to a dataframe named 'df'
# ![image.png](attachment:image.png)

# %%
df= pd.read_csv('Indiv. Proj. 1.csv')

# %%
df.head()
# Out:
#   initials      date course_id  time (m)                      summary
# 0       RH  9/3/2023  MATH-403     120.0                          HW1
# 1       RH  9/3/2023  THEO-334      45.0        prophetic imagination
# 2       RH  9/4/2023  THEO-334      60.0  prophetic imagination & RO2
# 3       RH  9/4/2023    DS-160     120.0             podcast. Summ. 1
# 4       RH  9/5/2023    DS-160      80.0                 gro. Proj. 1

# %% [markdown]
# ### Investigate your dataset

# %%
df.tail()
# Out:
#     initials date course_id  time (m) summary
# 495       RH  NaN       NaN       NaN     NaN
# 496       RH  NaN       NaN       NaN     NaN
# 497       RH  NaN       NaN       NaN     NaN
# 498       RH  NaN       NaN       NaN     NaN
# 499       RH  NaN       NaN       NaN     NaN

# %%
df.describe()
# Out:
#          time (m)
# count   61.000000
# mean    85.655738
# std     34.369020
# min     30.000000
# 25%     75.000000
# 50%     75.000000
# 75%     80.000000
# max    240.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   initials   500 non-null    object
#  1   date       61 non-null     object
#  2   course_id  61 non-null     object
#  3   time (m)   61 non-null     float64
#  4   summary    61 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 19.7+ KB

# %% [markdown]
# ### Summary Statistics
# Calculate basic statistics for the 'Time (minutes)' column, such as mean, median, minimum, and maximum. This will give you an overview of how time is distributed across activities. use table and graphical representations
# ![image.png](attachment:image.png)

# %%
df.describe()
sns.boxplot(y='time (m)',x='course_id',data=df)
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='course_id', ylabel='time (m)'>

# %% [markdown]
# ### Create two new columns "day" and "day_name" using the "Date" column in which the day will represent the range of days
# ![image.png](attachment:image.png)

# %%
df['date'] = pd.to_datetime(df['date'])
df['day_name']=df['date'].dt.day_name()
df['day'] = range(1,len(df)+1)
df.head()
# Out:
#   initials       date course_id  time (m)                      summary  \
# 0       RH 2023-09-03  MATH-403     120.0                          HW1
# 1       RH 2023-09-03  THEO-334      45.0        prophetic imagination
# 2       RH 2023-09-04  THEO-334      60.0  prophetic imagination & RO2
# 3       RH 2023-09-04    DS-160     120.0             podcast. Summ. 1
# 4       RH 2023-09-05    DS-160      80.0                 gro. Proj. 1
#
#   day_name  day
# 0   Sunday    1
# 1   Sunday    2
# 2   Monday    3
# 3   Monday    4
# 4  Tuesday    5

# %% [markdown]
# ### Data Visualization:
# 1. Create a histogram or bar chart to visually represent the distribution of time spent.
# 2. Create a  bar chart to visually represent the distribution of time spent on different courses and comment on the course you spent most and least time
# ![image-3.png](attachment:image-3.png)

# %%
sns.histplot(x='time (m)',data=df)
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='time (m)', ylabel='Count'>

# %%
sns.barplot(y='time (m)',x='course_id',data=df)
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='course_id', ylabel='time (m)'>

# %% [markdown]
# ### Activity Counts:
#
# Count the occurrences of each course in the dataset to see how often you engaged in each.

# %%
sns.histplot(x='course_id',data=df,stat='count')
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='course_id', ylabel='Count'>

# %%
df['course_id'].value_counts()
# Out:
# course_id
# FINA-315    16
# THEO-334    15
# MATH-403    11
# DS-160      10
# ECON-231     7
# HON-353H     2
# Name: count, dtype: int64

# %% [markdown]
# ### Time Trends:
#
# Plot a line chart to visualize how time spent on activities changes over the observed days.
# ![image.png](attachment:image.png)

# %%
sns.lineplot(x='day',y='time (m)',data=df)
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='day', ylabel='time (m)'>

# %% [markdown]
# ### Course Analysis:
#
# For each course ex.(DS 160, CS 150, CS 440), calculate the total time spent. Which course received the most time, and which received the least?
# - Sample print statement: Total time spent on CS160: 180 min

# %%
DS160= df.query('course_id=="DS-160"')['time (m)'].sum()
print(f'Total time spent on DS160: {DS160}')
# Out:
# Total time spent on DS160: 980.0

# %%
THEO334= df.query('course_id=="THEO-334"')['time (m)'].sum()
print(f'Total time spent on THEO334: {THEO334}')
# Out:
# Total time spent on THEO334: 1245.0

# %%
MATH403= df.query('course_id=="MATH-403"')['time (m)'].sum()
print(f'Total time spent on MATH403: {MATH403}')
# Out:
# Total time spent on MATH403: 1050.0

# %%
ECON231= df.query('course_id=="ECON-231"')['time (m)'].sum()
print(f'Total time spent on ECON231: {ECON231}')
# Out:
# Total time spent on ECON231: 525.0

# %%
FINA315= df.query('course_id=="FINA-315"')['time (m)'].sum()
print(f'Total time spent on FINA315: {FINA315}')
# Out:
# Total time spent on FINA315: 1185.0

# %%
HON353H = df.query('course_id=="HON-353H"')['time (m)'].sum()
print(f'Total tiem spent on HON353H: {HON353H}')
# Out:
# Total tiem spent on HON353H: 240.0

# %% [markdown]
# ### Correlations:
# - Examine whether there are any correlations between the day and the time spent. For example, do you spend more time on courses over days or less.
# ![image.png](attachment:image.png)

# %%
heat_map=df[['day','time (m)']].corr()
cols=['day','time (m)']

print(heat_map)
sns.heatmap(heat_map,xticklabels=cols, yticklabels=cols,annot=True)
# Out:
#               day  time (m)
# day       1.00000   0.21115
# time (m)  0.21115   1.00000
# <Axes: >
